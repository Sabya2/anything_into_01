# %% [markdown]
# # Assignment 03
# #### Python Basics III - Functions and Classes
#
# This tutorial was written by Terry L. Ruas (University of Göttingen). The references for external contributors for which this material was anyhow adapted/inspired are in the Acknowledgments section (end of the document).

# %% [markdown]
# This notebook will cover the following tasks:
#
# 1. Dictionary
# 2. Classes

# %% [markdown]
# ## Task 01 – Dictionary
# Imagine you have to write a (very simple) bookkeepingsystem for a bank that keeps track of the account balances of each of its customers.
# 1. Write a function that spans a dictionary holding a default balance of 0 for an initial list of customers. For simplicity, assume customer names are unique identifier.  (optional) Can you express that same functionality using a lambda function?
# 2. What are elegant ways to add or remove single and multiple customers using the functionality of dict?
# 3. Now write two simple functions that allow you to deposit and withdraw money for a given bank customer.
# 4. Include error messages for inputs that are not permissible, e.g., withdrawing negative amounts or overdrawing the account, etc.

# %%
#initial list of customers
customers = ['Pete','Mike','Lucho', 'nuser1', 'nuser2', 'nuser3']

#make a dict with balance 0 for each customer
def custom_balance(name):
    b = {value: 0 for value in name}
    return b

balance = custom_balance(customers)

#with dict comprehension
begining_balance = 0
clients = {key:begining_balance for key in customers}
clients
# Out:
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser1': 0, 'nuser2': 0, 'nuser3': 0}

# %%
#with dict.fromkeys function
clients = dict.fromkeys(customers, 0) 
clients
# Out:
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser1': 0, 'nuser2': 0, 'nuser3': 0}

# %%
print(balance)
print(clients)
# Out:
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser1': 0, 'nuser2': 0, 'nuser3': 0}
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser1': 0, 'nuser2': 0, 'nuser3': 0}

# %%
#adding people manually
balance['Ryan'] = 0
balance['Brian'] = 15
balance
# Out:
# {'Pete': 0,
#  'Mike': 0,
#  'Lucho': 0,
#  'nuser1': 0,
#  'nuser2': 0,
#  'nuser3': 0,
#  'Ryan': 0,
#  'Brian': 15}

# %%
# adding multiple people
new_users = ['Tony','Sam','Sergio']
balance.update({value:0 for value in new_users})
print(balance)
# deleting with del
del balance['nuser1']
print(balance)

# deleting with pop
balance.pop('nuser2')
balance.pop('nuser3')
print(balance)

# deleting last element
balance.popitem()
print(balance)

print(balance)
# Out:
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser1': 0, 'nuser2': 0, 'nuser3': 0, 'Ryan': 0, 'Brian': 15, 'Tony': 0, 'Sam': 0, 'Sergio': 0}
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'nuser2': 0, 'nuser3': 0, 'Ryan': 0, 'Brian': 15, 'Tony': 0, 'Sam': 0, 'Sergio': 0}
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'Ryan': 0, 'Brian': 15, 'Tony': 0, 'Sam': 0, 'Sergio': 0}
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'Ryan': 0, 'Brian': 15, 'Tony': 0, 'Sam': 0}
# {'Pete': 0, 'Mike': 0, 'Lucho': 0, 'Ryan': 0, 'Brian': 15, 'Tony': 0, 'Sam': 0}

# %%
def insert_money(accounts, customer, amount):
    if customer not in accounts:
        print(f'User {customer} not found, canceling')
    elif type(amount) != int and type(amount) != float:
        print('Non-numeric input, canceling...')
    elif amount < 0:
        print('Cannot add negative money, canceling...')
    else:
        print('Transaction succesful, thanks for trusting us')
        accounts[customer] += amount
    return accounts

def extract_money(accounts, user, amount):
    if user not in accounts:
        print(f'User {user} not found, canceling...')
    elif type(amount) != int and type(amount) != float:
        print('Non-numeric input, canceling...')
    elif amount > accounts[user]:
        print("You can/'t take more money than what you have, canceling...")
    else:
        print('Transaction succesful, thanks for trusting us.')
        accounts[user] -= amount
    return accounts

# %%
balance = insert_money(balance, 'Lucho', 50)
balance = insert_money(balance, 'Sandra', -5)
balance = insert_money(balance, 'Pete', 5)

balance = extract_money(balance, 'alice', 15)
balance = extract_money(balance, 'Brian', 15)
balance = extract_money(balance, 'Lucho', 15)

print(f'\n{balance}')
# Out:
# Transaction succesful, thanks for trusting us
# User Sandra not found, canceling
# Transaction succesful, thanks for trusting us
# User alice not found, canceling...
# Transaction succesful, thanks for trusting us.
# Transaction succesful, thanks for trusting us.
#
# {'Pete': 5, 'Mike': 0, 'Lucho': 35, 'Ryan': 0, 'Brian': 0, 'Tony': 0, 'Sam': 0}

# %% [markdown]
# ## Task 02 – Classes
# The manager thinks that the simple bookkeeping system you have built is not powerful enough. She requests that you start from scratch and use classes instead.
# 1. Write a simple class with appropriate constructor *\_\_init\_\_* that initializes an object of class *Customer* tracking the same information as in Task 01.
# 2. Now write two simple methods for class *Customer* that allow you to deposit and withdraw money for a given customer object.
# 3. Include error messages for inputs that are not permissible, e.g., withdrawing negative amounts or overdrawing the account.
# 4. (Inheritance) Write a child class *SavingsCustomer* that inherits its features from the parent class *Customer*. A savings customer has an extra savings balance for receiving extra interest. The class should have a method to transfer money back and forth between the accounts' main balance as well as the savings balance. Do not forget to add reasonable error messages.

# %%
class Customer():
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance
        
    def __str__(self):
        return f"{self.name} \thas a balance of ${self.balance}."
        
    def deposit(self, amount):
        while True:
            try:
                if isinstance(amount, int):
                    self.balance += amount
                    print(f"{self.name} deposited ${amount}, the new balance is ${self.balance}.")
                    break
                else:
                    raise ValueError
            except ValueError:
                try:
                    amount = int(input(f"Please input a valid amount of money to deposit: "))
                except:
                    continue
        
    def extract(self, amount):
        while True:
            try:
                if isinstance(amount, int):
                    if self.balance - amount >= 0:
                        self.balance -= amount
                        print(f"{self.name} withdrew ${amount}, the new balance is ${self.balance}.")
                        break
                    else:
                        raise BalanceError
                else:
                    raise ValueError
            except ValueError:
                try:
                    amount = int(input(f"Please input a valid amount of money to withdraw: "))
                except:
                    continue
            except BalanceError:
                try:
                    amount = int(input(f"{self.name}, you may not withdraw amounts higher than your balance (${self.balance}).\nPlease input a valid amount of money to withdraw: "))
                except:
                    continue
Brian = Customer('Brian Bo')
Lucho = Customer('Lucho Amoeba')

print(Brian)
print(Lucho)

Brian.deposit(130)
Lucho.deposit(1000)

Brian.extract(130)
Lucho.extract(1000)
# Out:
# Brian Bo 	has a balance of $0.
# Lucho Amoeba 	has a balance of $0.
# Brian Bo deposited $130, the new balance is $130.
# Lucho Amoeba deposited $1000, the new balance is $1000.
# Brian Bo withdrew $130, the new balance is $0.
# Lucho Amoeba withdrew $1000, the new balance is $0.
